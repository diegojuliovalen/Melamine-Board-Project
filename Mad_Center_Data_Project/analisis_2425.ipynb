# %% [markdown]
# TOTAL SALES PER STORE

# %%
import pandas as pd
import numpy as np

mad_df = pd.read_csv(
    "mad_center_data.csv", delimiter=";", parse_dates=["FECHA"], index_col="FECHA")

mad_df.groupby("SUCURSAL")["TOTAL"].sum().sort_values(ascending=False)
# Out:
# C:\Users\usuario\AppData\Local\Temp\ipykernel_14904\1890416550.py:4: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   mad_df = pd.read_csv(
# SUCURSAL
# Alm Suc 6 Cota Cota               12662490.54
# Alm Suc2 Juan Pablo II            10049972.48
# Alm Suc10 C. Viacha                7846640.63
# Alm Suc4 Blanco Galindo Km5.4      7320346.50
# Alm Suc5 3er Anillo Mutualista     5276037.36
# Alm Suc7 Miraflores                5085300.76
# Alm Suc9 Uniteb                    4265908.06
# Alm Suc12 Tarija                   2772388.31
# Alm Suc8 S. Dumont                 1671132.43
# Name: TOTAL, dtype: float64

# %% [markdown]
# TYPE OF PRODUCT RANKING

# %%
mad_df["FAMILIA"].value_counts(dropna=False).head(10)
# Out:
# FAMILIA
# TABLERO         28205
# TAPACANTO       26719
# SERVICIOS       14938
# HERRAJES         5783
# CONSTRUCCION     2519
# DRYWALL           613
# ADHESIVO          530
# TORNILLERIA       226
# MEBEL              21
# Name: count, dtype: int64

# %% [markdown]
# TOP VENDORS IN THE COMPANY

# %%
mad_df.groupby("VENDEDOR")["TOTAL"].sum().sort_values(ascending=False)
# Out:
# VENDEDOR
# Israel Ramirez                 11200118.48
# Lizet Quenta                   10049972.48
# Jimena Roca                     7128388.30
# Pamela Salcedo                  5209514.45
# Mauricio Reguerin               5085300.76
# Virginia Villarroel             4265908.06
# MARIA CHOCLLO                   3083305.02
# Jorge Condori Q                 2772383.02
# Raulito Mamani                  2637125.29
# Marco Roca                      1671132.43
# Ana Chocllo                     1200470.37
# Evelyn Mollo Flores              992261.97
# Americo Rojas                    654360.99
# Diva Pozadas                     433648.40
# Erika Adriana Zegales Pardo      320935.02
# Marcia Espinoza                  191958.20
# Wilmer Condori                    53427.65
# Luis Quiroga                          5.29
# Raul Mamani                           0.89
# Name: TOTAL, dtype: float64

# %% [markdown]
# TOP TABLETOP PRODUCTS PER STORE

# %%
mad_df["CANT."] = pd.to_numeric(mad_df["CANT."], errors="coerce")

melaminas = mad_df[
    mad_df["Sustrato"].isin(["MADERADO", "SYNCHRONICO"]) |
    (mad_df["FAMILIA"] == "TABLERO")
]


top10 = (
    melaminas
    .groupby(["SUCURSAL", "DESCRIPCIÓN"])["CANT."]
    .sum()
    .sort_values(ascending=False)
    .groupby(level=0)
    .head(20)
)

for sucursal, datos in top10.groupby(level=0):
    print(f"\n===== {sucursal} =====")
    print(datos.reset_index(level=0, drop=True))
# Out:
# ===== Alm Suc 6 Cota Cota =====
# DESCRIPCIÓN
# MDP PELIK MEL 2C BLANCO 15mm              4112.0
# MDP PELIK MEL 2C BLANCO 18mm              1970.0
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5M
# MDP EUX MEL 2C MONTANA SUPER BRILLO 12MM              105.0
# MDP PELIK MEL 2C CAPRI 15MM                           101.0
# MDP EUX MEL 2C FREIJO CAF SUPER BRILLO NG 12MM        100.0
# Name: CANT., dtype: float64

# %% [markdown]
# TOP TABLETOP PRODUCTS PER STORE ONLY 15MM

# %%
mad_df["CANT."] = pd.to_numeric(mad_df["CANT."], errors="coerce")

melaminas = mad_df[
    mad_df["Sustrato"].isin(["MADERADO", "SYNCHRONICO"]) |
    (mad_df["FAMILIA"] == "TABLERO")
]

melaminas_15mm = melaminas[melaminas["Espesor / Medida"] == "15MM"]

top20_15mm = (
    melaminas_15mm
    .groupby(["SUCURSAL", "DESCRIPCIÓN"])["CANT."]
    .sum()
    .sort_values(ascending=False)
    .groupby(level=0)
    .head(20)
)

for sucursal, datos in top20_15mm.groupby(level=0):
    print(f"\n===== {sucursal} =====")
    print(datos.reset_index(level=0, drop=True))
# Out:
# ===== Alm Suc 6 Cota Cota =====
# DESCRIPCIÓN
# MDP PELIK MEL 2C BLANCO 15mm                4112.0
# MDP PELIK MEL 2C CARAMELO 15mm               510.0
# MDP PELIK MEL 2C ROVERE 15mm                 424.0
# MDP PELIK MEL 2C CEDRO 15mm                  366.0
# MDP PELIK MEL 2C PLOMO 15mm                  359.0
# MDP PELIK MEL 2C DUNA 15MM                   358.0
# MDP PELIK MEL 2C TAUPE 15MM                  327.0
# MDP PELIK MEL 2C MANZANO 15mm                262.0
# MDP PELIK MEL 2C ARTICO 15mm                 250.0
# MDP PELIK MEL 2C LINO 15mm                   248.0
# MDP PELIK MEL 2C HABANO 15mm                 219.0
# MDP PELIK MEL 2C ESPRESO 15mm                217.0
# MDP PELIK MEL 2C SYNC ROBLE BELLOTA 15MM     198.0
# MDP PELIK MEL 2C NIEBLA 15MM                 164.0
# MDP PELIK MEL 2C GALES 15MM                  144.0
# MDP PELIK MEL 2C CAPRI 15MM                  133.0
# MDP PELIK MEL 2C CEMENTO 15mm                109.0
# MDP PELIK MEL 2C ONIX 15MM                   105.0
# MDP PELIK MEL 2C GRIS 15mm                   100.0
# MDP PELIK MEL 2C WENGUE 15mm                  92.0
# Name: CANT., dtype: float64
#
# ===== Alm Suc10 C. Viacha =====
# DESCRIPCIÓN
# MDP PELIK MEL 2C BLANCO 15mm                2284.0
# MDP PELIK MEL 2C TAUPE 15MM                  769.0
# MDP PELIK MEL 2C CEDRO 15mm                  380.0
# MDP PELIK MEL 2C WENGUE 15mm                 243.0
# MDP PELIK MEL 2C ROVERE 15mm                 232.0
# MDP PELIK MEL 2C CARAMELO 15mm               222.0
# MDP PELIK MEL 2C PLOMO 15mm                  201.0
# MDP REPINH MEL 2C BLANCO 15MM                178.0
# MDP PELIK MEL 2C DUNA 15MM                   158.0
# MDP PELIK MEL 2C HABANO 15mm                 134.0
# MDP PELIK MEL 2C CAPRI 15MM                  107.0
# MDP PELIK MEL 2C SYNC NOGAL NACAR 15MM        99.0
# MDP PELIK MEL 2C ESPRESO 15mm                 90.0
# MDP DURATEX MEL 2C NOCE AMENDOA 15MM          89.0
# MDP PELIK MEL 2C SYNC ROBLE BELLOTA 15MM      73.0
# MDP PELIK MEL 2C LINO 15mm                    70.0
# MDP PELIK MEL 2C ARTICO 15mm                  69.0
# MDP PELIK MEL 2C NIEBLA 15MM                  68.0
# MDP PELIK MEL 2C ONIX 15MM                    67.0
# MDP EUX MEL-HG 2C FUME 15MM                   67.0
# Name: CANT., dtype: float64
#
# ===== Alm Su
0
# MDP EUX MEL- 2C NOCE ORO NATURAL 15MM    24.0
# MDP PELIK MEL 2C GALES 15MM              16.0
# MDP PELIK MEL 2C PLOMO 15mm              15.0
# MDP DURATEX MEL 2C ALAMO 15MM            14.0
# MDP EUX MEL 2C LEGNO CREMA 15mm          14.0
# MDP DURATEX MEL 2C NOCE AMENDOA 15MM      9.0
# MDF EUX BERNK CRUDO 2C NATURAL 15MM       8.0
# MDP EUX MEL 2C IMBUIA TERRA 15MM          4.0
# MDP DURATEX MEL 2C PIGNETTO 15MM          3.0
# MDP EUX MEL-HG 2C FUME 15MM               3.0
# MDP EUX MEL 2C ELMO MACCIATO 15MM         2.0
# MDP PELIK MEL 2C CEMENTO 15mm             2.0
# MDP EUX MEL 2C CASTAÑO BRONCE 15MM        1.0
# MDP PELIK MEL 2C OLIVO 15mm               1.0
# Name: CANT., dtype: float64
#
# ===== Alm Suc9 Uniteb =====
# DESCRIPCIÓN
# MDP PELIK MEL 2C BLANCO 15mm                          883.0
# MDP PELIK MEL 2C ESPRESO 15mm                         266.0
# MDP PELIK MEL 2C CARAMELO 15mm                        234.0
# MDP REPINH MEL 2C BLANCO 15MM                         208.0
# MDP PELIK MEL 2C ROVERE 15mm                          157.0
# MDP EUX MEL 2C FREIJO CAF SB NG 15MM                  141.0
# MDP PELIK MEL 2C PLOMO 15mm                           140.0
# MDP PELIK MEL 2C CEMENTO 15mm                         117.0
# MDP EUX MEL 2C CASTAÑO TANNAT SUPER BRILLO NG 15MM    108.0
# MDP PELIK MEL 2C CAPRI 15MM                           101.0
# MDP PELIK MEL 2C TAUPE 15MM                            96.0
# MDP PELIK MEL 2C LINO 15mm                             93.0
# MDP PELIK MEL 2C DUNA 15MM                             85.0
# MDP EUX MEL 2C MONTANA SUPER BRILLO 15MM               59.0
# MDP PELIK MEL 2C ARTICO 15mm                           56.0
# MDP PELIK MEL 2C HABANO 15mm                           53.0
# MDP PELIK MEL 2C CONAC 15MM                            49.0
# MDP PELIK MEL 2C WENGUE 15mm                           46.0
# MDP PELIK MEL 2C ONIX 15MM                             46.0
# MDP EUX MEL- 2C NOCE ORO NATURAL 15MM                  45.0
# Name: CANT., dtype: float64

# %% [markdown]
# TOP TABLETOP PRODUCTS PER STORE ONLY 18MM

# %%
mad_df["CANT."] = pd.to_numeric(mad_df["CANT."], errors="coerce")

melaminas = mad_df[
    mad_df["Sustrato"].isin(["MADERADO", "SYNCHRONICO"]) |
    (mad_df["FAMILIA"] == "TABLERO")
]
melaminas_18mm = melaminas[melaminas["Espesor / Medida"] == "18MM"]

top20_18mm = (
    melaminas_18mm
    .groupby(["SUCURSAL", "DESCRIPCIÓN"])["CANT."]
    .sum()
    .sort_values(ascending=False)
    .groupby(level=0)
    .head(20)
)

for sucursal, datos in top20_18mm.groupby(level=0):
    print(f"\n===== {sucursal} (18MM) =====")
    print(datos.reset_index(level=0, drop=True))
# Out:
# ===== Alm Suc 6 Cota Cota (18MM) =====
# DESCRIPCIÓN
# MDP PELIK MEL 2C BLANCO 18mm
0
# Name: CANT., dtype: float64
#
# ===== Alm Suc9 Uniteb (18MM) =====
# DESCRIPCIÓN
# MDP PELIK MEL 2C DUNA 18MM            168.0
# MDP PELIK MEL 2C ROVERE 18mm          157.0
# MDP PELIK MEL 2C LINO 18mm            140.0
# MDP PELIK MEL 2C CEDRO 18mm           127.0
# MDP PELIK MEL 2C CARAMELO 18mm        127.0
# MDP PELIK MEL 2C CAPRI 18MM           120.0
# MDP PELIK MEL 2C BLANCO 18mm          119.0
# MDP REPINH MEL 2C BLANCO 18MM          96.0
# MDP PELIK MEL 2C GALES 18MM            86.0
# MDP PELIK MEL 2C ARTICO 18mm           81.0
# MDP PELIK MEL 2C TAUPE 18MM            73.0
# MDP PELIK MEL 2C ESPRESO 18mm          63.0
# MDP PELIK MEL 2C PLOMO 18mm            51.0
# MDP EUX MEL 2L BLANCO PERFECT 18MM     46.0
# MDP EUX MEL-HG 2C BLANCO 18 mm         43.0
# MDP REPINH MEL 2C FREIJO AMAZ 18MM     43.0
# MDP PELIK MEL 2C NIEBLA 18MM           42.0
# MDP PELIK MEL 2C CENIZA 18mm           35.0
# MDP PELIK MEL 2C ROBLE GRIS 18mm       33.0
# MDP PELIK MEL 2C ONIX 18MM             30.0
# Name: CANT., dtype: float64

# %% [markdown]
# TOP TABLETOP PRODUCTS PER STORE ALL OTHERS

# %%
mad_df["CANT."] = pd.to_numeric(mad_df["CANT."], errors="coerce")

melaminas = mad_df[
    mad_df["Sustrato"].isin(["MADERADO", "SYNCHRONICO"]) |
    (mad_df["FAMILIA"] == "TABLERO")
]
otros_espesores = melaminas[~melaminas["Espesor / Medida"].isin(["15MM", "18MM"])]

top20_otros = (
    otros_espesores
    .groupby(["SUCURSAL", "DESCRIPCIÓN"])["CANT."]
    .sum()
    .sort_values(ascending=False)
    .groupby(level=0)
    .head(20)
)

for sucursal, datos in top20_otros.groupby(level=0):
    print(f"\n===== {sucursal} (OTROS ESPESORES) =====")
    print(datos.reset_index(level=0, drop=True))
# Out:
# ===== Alm Suc 6 Cota Cota (OTROS ESPESORES) =====
# DESCRIPCIÓN
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5MM                      1041.0
# MDP PELIK PANEL CHAPA 2C NATURAL SAPELLI 37mm                141.0
# MDP PELIK MEL 2C NIEBLA 36mm                                  95.0
# MDP PELIK MEL 1C TAUPE 6mm                                    71.0
# THDF EUX FONDO 1C MOGNO UBATUBA 2,5MM                         58.0
# MDP PELIK MEL 1C LINO 6mm                                     44.0
# MDP PELIK MEL 1C BLANCO 6MM                                   42.0
# MDF EUX GPLAC CRUDO 2C NATURAL 9MM                            37.0
# THDF EUX FONDO 1C CRISTAL 2,5MM                               37.0
# THDF EUX FONDO 1C IMBUIA QUARTIER 2,5MM                       35.0
# MDP PELIK MEL 1C GALES 6mm                                    34.0
# MDP PELIK MEL 1C ROVERE 6mm                                   32.0
# MDF EUX GPLAC CRUDO 2C NATURAL 12MM                           32.0
# MDP PELIK MELRHTROPK 2C CHAPA SAPELLI 37MM                    29.0
# MDF EUX BERNK CRUDO 2C NATURAL 6MM                            28.0
# MDP PELIK MEL 1C CARAMELO 6mm                                 28.0
# MDP PELIK MEL 1C NIEBLA 9MM                                   26.0
# MDP PELIK MEL 1C PLOMO 6mm                                    25.0
# THDF EUX FONDO 1C AREIA JUNDIAI UV LAB 2.5MM (2,13*2,75)      20.0
# MDP PELIK MEL 1C SIENA 6mm                                    18.0
# Name: CANT., dtype: float64
#
# ===== Alm Suc10 C. Viacha (OTROS ESPESORES) =====
# DESCRIPCIÓN
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5MM        409.0
# MDP PELIK MEL 2C BLANCO 18mm                  113.0
# MDP PELIK MEL 1C CEMENTO 6mm                   60.0
# MDP PELIK MEL 1C MANZANO 6mm                   54.0
# MDP PELIK MEL 1C MIEL 6mm                      52.0
# MDP PELIK MEL 2C BLANCO 15mm                   48.0
# MDP PELIK MEL 2C GRIS 25mm                     46.0
# MDP PELIK MEL 1C CARBON 6mm                    46.0
# MDP PELIK MEL 1C DUNA 6mm                      44.0
# MDF EUX GPLAC CRUDO 2C NATURAL 12MM            42.0
# MDP PELIK MEL 2C CEDRO 18mm                    41.0
# MDP PELIK MEL 1C CENIZA 6mm                    41.0
# MDP EUX MEL ACET 1L CASTAÑO VELASQUEZ 12mm     38.0
# THDF EUX FONDO 1C IMBUIA QUARTIER 2,5MM        36.0
# MDP PELIK MEL 2C GALES 15MM                    34.0
# MDP PELIK MEL 1C ROBLE GRIS 6mm                32.0
# MDP PELIK MEL 1C NIEBLA 6mm                    32.0
# MDP PELIK MEL 1C ESPRESO 6mm                   30.0
# MDP PELIK MEL 1C CEDRO 6mm                     28.0
# MDP PELIK MEL 1C PLOMO 6mm                     24.0
# Name: CANT., dtype: float64
#
# ===== Alm Suc12 Tarija (OTROS ESPESORES) =====
# DESCRIPCIÓN
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5MM                    516.0
# THDF EUX FONDO 1C FRESNO NOBRE 2,5MM                       67.0
# THDF EUX FONDO 1C TEKA MILANO UV LAB 2.5MM (2,13*2,75)     34.0
# THDF EUX FONDO 1C IMBUIA QUARTIER 2,5MM                    25.0
# THDF EUX FONDO 1C MOGNO UBATUBA 2,5MM                      21.0
# MDP PELIK MEL 1C HABANO 6mm                                17.0
# MDP PELIK MEL 1C DUNA 6mm                                  13.0
# THDF EUX FONDO 1C FRESNO SBIANCATO 2,5MM (2,13*2,75)       10.0
# THDF EUX FONDO 1C CRISTAL 2,5MM                            10.0
# MDP PELIK MEL 1C GALES 6mm                                  9.0
# MDP PELIK MEL 1C CEMENTO 6mm                                8.0
# MDP PELIK MEL 1C MANZANO 6mm                                8.0
# MDP PELIK MEL 1C BLANCO 6MM                                 7.0
# MDP PELIK MEL 1C CEDRO 6mm                                  5.0
# MDP PELIK MEL 1C SAPELLI 6mm                                5.0
# MDP PELIK MEL 1C TAUPE 6mm                                  5.0
# MDP PELIK MEL 1C ROVERE 6mm                                 4.0
# MDP PELIK MEL 1C CENIZA 6mm                                 4.0
# MDP PELIK MEL 1C ARTICO 6mm                                 3.0
# MDF EUX GPLAC CRUDO 2C NATURAL 12MM                         2.0
# Name: CANT., dtype: float64
#
# ===== Alm Suc2 Juan Pablo II (OTROS ESPESORES) =====
# DESCRIPCIÓN
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5MM                546.0
# MDP PELIK MEL 1C CEDRO 6mm                             87.0
# MDP PELIK MEL 1C ARTICO 6mm                            58.0
# MDP EUX MEL 2C CASTAÑO TANNAT SUPER BRILLO NG 12MM     52.0
# THDF EUX FONDO 1C FRESNO NOBRE 2,5MM                   49.0
# MDP EUX MEL 2C MONTANA SUPER BRILLO 12MM               47.0
# MDP PELIK MEL 1C BLANCO 6MM                            43.0
# THDF EUX FONDO 1C MOGNO UBATUBA 2,5MM                  35.0
# MDP PELIK MEL 1C HABANO 6mm                            32.0
# MDP PELIK MEL 1C ESPRESO 6mm                           30.0
# MDP PELIK MEL 1C CARAMELO 6mm                          29.0
# MDP PELIK MEL 1C SAPELLI 6mm                           25.0
# MDP PELIK MEL 1C NIEBLA 6mm                            25.0
# MDP PELIK MEL 1C PLOMO 6mm                             23.0
# MDP PELIK MEL 1C CARBON 6mm                            22.0
# THDF EUX FONDO 1C IMBUIA QUARTIER 2,5MM                20.0
# MDP PELIK MEL 1C GALES 6mm                             17.0
# MDP PELIK MEL 1C HAYA CATEDRAL 6mm                     17.0
# MDP PELIK MEL 1C DUNA 6mm                              16.0
# MDP PELIK MEL 1C CENIZA 6mm                            16.0
# Name: CANT., dtype: float64
#
# ===== Alm Suc4 Blanco Galindo Km5.4 (OTROS ESPESORES) =====
# DESCRIPCIÓN
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5MM                      535.0
# MDP PELIK MEL 1C DUNA 6mm                                    94.0
# MDP PELIK MEL 1C ROVERE 6mm                                  88.0
# THDF EUX FONDO 1C IMBUIA QUARTIER 2,5MM                      75.0
# MDP PELIK MEL 1C HABANO 6mm                                  72.0
# MDP PELIK MEL 1C CARAMELO 6mm                                58.0
# MDP PELIK MEL 1C WENGUE 6mm                                  56.0
# MDF EUX GPLAC CRUDO 2C NATURAL 6MM                           49.0
# THDF EUX FONDO 1C AREIA JUNDIAI UV LAB 2.5MM (2,13*2,75)     48.0
# MDP PELIK MEL 1C HAYA CATEDRAL 6mm                           45.0
# MDF EUX GPLAC CRUDO 2C NATURAL 12MM                          41.0
# MDP PELIK MEL 1C BLANCO 6MM                                  40.0
# MDF EUX GPLAC CRUDO 2C NATURAL 9MM                           31.0
# THDF EUX FONDO 1C EUCAPLAC IMBUIA RUBI 2,5MM (2,13*2,75)     30.0
# MDP PELIK MEL 1C PLOMO 6mm                                   28.0
# MDP PELIK MEL 1C ONIX 6mm                                    25.0
# THDF EUX FONDO 1C FRESNO SBIANCATO 2,5MM (2,13*2,75)         22.0
# MDP PELIK MEL 1C CEDRO 6mm                                   21.0
# THDF EUX FONDO 1C TEKA MILANO UV LAB 2.5MM (2,13*2,75)       21.0
# THDF EUX FONDO 1C FRESNO NOBRE 2,5MM                         20.0
# Name: CANT., dtype: float64
#
# ===== Alm Suc5 3er Anillo Mutualista (OTROS ESPESORES) =====
# DESCRIPCIÓN
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5MM                      1019.0
# THDF EUX FONDO 1C FRESNO NOBRE 2,5MM                         146.0
# MDF EUX BERNK CRUDO 2C NATURAL 9MM                           128.0
# THDF EUX FONDO 1C CRISTAL 2,5MM                               96.0
# THDF EUX FONDO 1C MOGNO UBATUBA 2,5MM                         92.0
# MDF EUX GPLAC CRUDO 2C NATURAL 9MM                            72.0
# THDF EUX FONDO 1C TEKA MILANO UV LAB 2.5MM (2,13*2,75)        68.0
# THDF EUX FONDO 1C IMBUIA QUARTIER 2,5MM                       57.0
# THDF EUX FONDO 1C AREIA JUNDIAI UV LAB 2.5MM (2,13*2,75)      43.0
# THDF EUX FONDO 1C CANELA UV 2.5MM (2.13*2.75)                 42.0
# THDF EUX FONDO 1C TABACO BRASIL 2,5MM                         25.0
# MDF EUX BERNK CRUDO 2C NATURAL 6MM                            13.0
# THDF EUX FONDO 1C MADEIRADO PR 2,5MM                          13.0
# THDF EUX FONDO 1C PRETO2,5MM                                  11.0
# THDF EUX FONDO 1C IMBUIA RUBI 3mm                             10.0
# MDF EUX BERNK CRUDO 2C NATURAL 12MM                           10.0
# MDP PELIK MEL 1C SAPELLI 6mm                                   7.0
# MDF EUX GPLAC CRUDO 2C NATURAL 12MM                            2.0
# MDP PELIK MEL 1C CEREZO 6mm                                    2.0
# THDF EUX FONDO 1C PM NOGAL MEL 3MM                             1.0
# Name: CANT., dtype: float64
#
# ===== Alm Suc7 Miraflores (OTROS ESPESORES) =====
# DESCRIPCIÓN
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5MM                      492.0
# THDF EUX FONDO 1C MOGNO UBATUBA 2,5MM                        64.0
# MDP PELIK MEL 1C SAPELLI 6mm                                 31.0
# THDF EUX FONDO 1C FRESNO NOBRE 2,5MM                         28.0
# MDP PELIK MEL 1C WENGUE 6mm                                  17.0
# MDP PELIK MEL 1C ESPRESO 6mm                                 15.0
# THDF EUX FONDO 1C CRISTAL 2,5MM                              13.0
# MDP PELIK MEL 1C ROVERE 6mm                                  10.0
# MDP PELIK MEL 1C ARTICO 6mm                                   9.0
# MDP PELIK MEL 1C MANZANO 6mm                                  8.0
# THDF EUX FONDO 1C CANELA UV 2.5MM (2.13*2.75)                 8.0
# MDP PELIK MEL 1C DUNA 6mm                                     7.0
# THDF EUX FONDO 1C IMBUIA QUARTIER 2,5MM                       7.0
# MDP PELIK MEL 1C BLANCO 6MM                                   6.0
# MDP PELIK MEL 1C CARAMELO 6mm                                 6.0
# THDF EUX FONDO 1C MOGNO LEON 2,5MM                            6.0
# THDF EUX FONDO 1C MADEIRADO PR 2,5MM                          5.0
# MDP PELIK MEL 1C ONIX 6mm                                     5.0
# THDF EUX FONDO 1C HARDBOARD BLANCO MEL 2.5MM (2,13*2,75)      4.0
# MDP PELIK MEL 1C LINO 6mm                                     3.0
# Name: CANT., dtype: float64
#
# ===== Alm Suc8 S. Dumont (OTROS ESPESORES) =====
# DESCRIPCIÓN
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5MM                      442.0
# THDF EUX FONDO 1C MOGNO UBATUBA 2,5MM                        43.0
# THDF EUX FONDO 1C FRESNO NOBRE 2,5MM                         17.0
# THDF EUX FONDO 1C AREIA JUNDIAI UV LAB 2.5MM (2,13*2,75)      7.0
# THDF EUX FONDO 1C IMBUIA QUARTIER 2,5MM                       2.0
# THDF EUX FONDO 1C CRISTAL 2,5MM                               1.0
# THDF EUX FONDO 1C MOGNO LEON 2,5MM                            1.0
# THDF EUX FONDO 1C TABACO BRASIL 2,5MM                         1.0
# Name: CANT., dtype: float64
#
# ===== Alm Suc9 Uniteb (OTROS ESPESORES) =====
# DESCRIPCIÓN
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5MM                    639.0
# MDP EUX MEL 2C MONTANA SUPER BRILLO 12MM                  105.0
# MDP EUX MEL 2C FREIJO CAF SUPER BRILLO NG 12MM            100.0
# MDP EUX MEL 2C CASTAÑO TANNAT SUPER BRILLO NG 12MM         90.0
# THDF EUX FONDO 1C IMBUIA QUARTIER 2,5MM                    83.0
# MDF EUX GPLAC CRUDO 2C NATURAL 9MM                         21.0
# MDP PELIK MEL 1C GALES 6mm                                 21.0
# THDF EUX FONDO 1C MOGNO UBATUBA 2,5MM                      20.0
# MDP PELIK MEL 1C CEDRO 6mm                                 19.0
# THDF EUX FONDO 1C CRISTAL 2,5MM                            18.0
# MDF EUX GPLAC CRUDO 2C NATURAL 6MM                         18.0
# THDF EUX FONDO 1C TEKA MILANO UV LAB 2.5MM (2,13*2,75)     18.0
# MDP PELIK MEL 1C HABANO 6mm                                13.0
# MDP PELIK MEL 1C PLOMO 6mm                                 13.0
# MDF EUX GPLAC CRUDO 2C NATURAL 12MM                        13.0
# MDP PELIK MEL 1C MANZANO 6mm                               11.0
# MDP PELIK MEL 1C TAUPE 6mm                                 11.0
# THDF EUX FONDO 1C CANELA UV 2.5MM (2.13*2.75)              11.0
# MDP PELIK MEL 1C LINO 6mm                                   9.0
# MDP PELIK MEL 1C DUNA 6mm                                   9.0
# Name: CANT., dtype: float64

# %% [markdown]
# GLOBAL RANKING OF 15MM TABLETOPS 2024 - 2025

# %%
mad_df["CANT."] = pd.to_numeric(mad_df["CANT."], errors="coerce")

melaminas = mad_df[
    mad_df["Sustrato"].isin(["MADERADO", "SYNCHRONICO"]) |
    (mad_df["FAMILIA"] == "TABLERO")
]
melaminas_15mm = melaminas[melaminas["Espesor / Medida"] == "15MM"]

ranking_15mm = (
    melaminas_15mm
    .groupby("DESCRIPCIÓN")["CANT."]
    .sum()
    .sort_values(ascending=False)
)

ranking_15mm.head(20)
# Out:
# DESCRIPCIÓN
# MDP PELIK MEL 2C BLANCO 15mm             15874.0
# MDP PELIK MEL 2C CARAMELO 15mm            2060.0
# MDP PELIK MEL 2C CEDRO 15mm               1779.0
# MDP REPINH MEL 2C BLANCO 15MM             1581.0
# MDP PELIK MEL 2C ROVERE 15mm              1457.0
# MDP PELIK MEL 2C TAUPE 15MM               1430.0
# MDP PELIK MEL 2C PLOMO 15mm               1286.0
# MDP PELIK MEL 2C DUNA 15MM                1157.0
# MDP PELIK MEL 2C ESPRESO 15mm             1155.0
# MDP PELIK MEL 2C CAPRI 15MM                802.0
# MDP PELIK MEL 2C WENGUE 15mm               760.0
# MDP PELIK MEL 2C LINO 15mm                 701.0
# MDP PELIK MEL 2C ONIX 15MM                 695.0
# MDP PELIK MEL 2C HABANO 15mm               679.0
# MDP PELIK MEL 2C NIEBLA 15MM               583.0
# MDP PELIK MEL 2C MANZANO 15mm              550.0
# MDP PELIK MEL 2C NEGRO 15mm                516.0
# MDP PELIK MEL 2C ARTICO 15mm               513.0
# MDP EUX MEL- 2C NOCE ORO NATURAL 15MM      511.0
# MDP PELIK MEL 2C GRIS 15mm                 490.0
# Name: CANT., dtype: float64

# %% [markdown]
# GLOBAL RANKING OF 18MM TABLETOPS 2024 - 2025

# %%
melaminas_18mm = melaminas[melaminas["Espesor / Medida"] == "18MM"]

ranking_18mm = (
    melaminas_18mm
    .groupby("DESCRIPCIÓN")["CANT."]
    .sum()
    .sort_values(ascending=False)
)

ranking_18mm.head(20)
# Out:
# DESCRIPCIÓN
# MDP PELIK MEL 2C BLANCO 18mm                7054.0
# MDP PELIK MEL 2C CARAMELO 18mm              1736.0
# MDP PELIK MEL 2C CEDRO 18mm                 1733.0
# MDP REPINH MEL 2C BLANCO 18MM               1473.0
# MDP PELIK MEL 2C PLOMO 18mm                 1364.0
# MDP PELIK MEL 2C ROVERE 18mm                1243.0
# MDP PELIK MEL 2C DUNA 18MM                  1157.0
# MDP PELIK MEL 2C GRIS 18mm                  1118.0
# MDP PELIK MEL 2C TAUPE 18MM                  991.0
# MDP PELIK MEL 2C ESPRESO 18mm                849.0
# MDP PELIK MEL 2C LINO 18mm                   849.0
# MDP PELIK MEL 2C WENGUE 18mm                 809.0
# MDP PELIK MEL 2C CAPRI 18MM                  717.0
# MDP PELIK MEL 2C GALES 18MM                  689.0
# MDP PELIK MEL 2C ARTICO 18mm                 622.0
# MDP PELIK MEL 2C HABANO 18mm                 571.0
# MDP PELIK MEL 2C NIEBLA 18MM                 567.0
# MDP PELIK MEL 2C CONAC 18MM                  555.0
# MDP PELIK MEL 2C NEGRO 18mm                  533.0
# MDP PELIK MEL 2C SYNC ROBLE BELLOTA 18MM     464.0
# Name: CANT., dtype: float64

# %% [markdown]
# GLOBAL RANKING OF SMALL TABLETOPS 2024 - 2025

# %%
otros_espesores = melaminas[~melaminas["Espesor / Medida"].isin(["15MM", "18MM"])]

ranking_otros = (
    otros_espesores
    .groupby("DESCRIPCIÓN")["CANT."]
    .sum()
    .sort_values(ascending=False)
)

ranking_otros.head(20)
# Out:
# DESCRIPCIÓN
# THDF EUX FONDO 1C BLANCO GLACIAL 2,5MM                      5639.0
# THDF EUX FONDO 1C MOGNO UBATUBA 2,5MM                        352.0
# THDF EUX FONDO 1C IMBUIA QUARTIER 2,5MM                      340.0
# THDF EUX FONDO 1C FRESNO NOBRE 2,5MM                         329.0
# THDF EUX FONDO 1C CRISTAL 2,5MM                              210.0
# MDP PELIK MEL 1C DUNA 6mm                                    195.0
# MDP PELIK MEL 1C CEDRO 6mm                                   173.0
# MDP PELIK MEL 1C BLANCO 6MM                                  168.0
# MDP EUX MEL 2C MONTANA SUPER BRILLO 12MM                     167.0
# MDF EUX GPLAC CRUDO 2C NATURAL 9MM                           162.0
# MDP PELIK MEL 1C HABANO 6mm                                  162.0
# MDP PELIK MEL 1C ROVERE 6mm                                  150.0
# MDP EUX MEL 2C CASTAÑO TANNAT SUPER BRILLO NG 12MM           146.0
# THDF EUX FONDO 1C TEKA MILANO UV LAB 2.5MM (2,13*2,75)       142.0
# MDF EUX GPLAC CRUDO 2C NATURAL 12MM                          142.0
# MDP PELIK PANEL CHAPA 2C NATURAL SAPELLI 37mm                141.0
# THDF EUX FONDO 1C AREIA JUNDIAI UV LAB 2.5MM (2,13*2,75)     137.0
# MDP PELIK MEL 1C CARAMELO 6mm                                132.0
# MDF EUX BERNK CRUDO 2C NATURAL 9MM                           128.0
# MDP PELIK MEL 1C TAUPE 6mm                                   115.0
# Name: CANT., dtype: float64

# %% [markdown]
# GLOBAL AVERAGE PRICE PER STORE 2024 - 2025

# %%
data = melaminas.copy() 

data["THICKNESS_CAT"] = np.where(
    data["Espesor / Medida"].isin(["15MM", "18MM"]),
    data["Espesor / Medida"].str.upper(),
    "OTHER"
)

pivot_branch = (
    data
    .groupby(["SUCURSAL", "THICKNESS_CAT"])["PRECIO"]
    .mean()
    .round(2)
    .unstack(fill_value=np.nan)
    .reset_index()
    
)

print("Average price per MM:")
print(pivot_branch.head(10))


overall = (
    data
    .groupby("THICKNESS_CAT")["PRECIO"]
    .mean()
    .round(2)
    .reset_index()
    .rename(columns={"PRECIO": "Average Price per MM"})
)

print("\nOverall average price 2024:")
print(overall)
# Out:
# Average price per MM:
# THICKNESS_CAT                        SUCURSAL    15MM    18MM   OTHER
# 0                         Alm Suc 6 Cota Cota  607.17  671.10  282.82
# 1                         Alm Suc10 C. Viacha  586.44  682.16  395.03
# 2                            Alm Suc12 Tarija  590.38  673.61  219.20
# 3                      Alm Suc2 Juan Pablo II  590.17  673.23  256.43
# 4               Alm Suc4 Blanco Galindo Km5.4  559.17  649.08  248.16
# 5              Alm Suc5 3er Anillo Mutualista  481.63  652.50  199.14
# 6                         Alm Suc7 Miraflores  574.51  655.53  231.57
# 7                          Alm Suc8 S. Dumont  482.20  599.93  201.50
# 8                             Alm Suc9 Uniteb  592.71  684.89  236.38
#
# Overall average price 2024:
#   THICKNESS_CAT  Average Price per MM
# 0          15MM                581.86
# 1          18MM                661.60
# 2         OTHER                254.44
